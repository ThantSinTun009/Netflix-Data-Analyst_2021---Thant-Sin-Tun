# %% [markdown]
# **Netflix Data Analyst**

# %% [markdown]
# **Project Description**

# %% [markdown]
# This project is designed to analyze the Netflix movie dataset from kaggle.
#
# ---
#
# In my project, I tried to answer targetted questions for common business goals through viusalization and analytics.
#
# ---
#
# This project targets global audience as Netflix is a popular streaming platforms.

# %% [markdown]
# ![Netflix.logo.webp](data:image/webp;base64,...)

# %% [markdown]
# **Import the libraries**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Understand the Data**

# %%
df = pd.read_csv("/content/netflixData.csv")

# %%
# Print the number of features, number of data points
print(df.shape)

# Print the information of the dataset and check data types
df.info()

df.describe()
# Out:
# (5967, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5967 entries, 0 to 5966
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Show Id             5967 non-null   object
#  1   Title               5967 non-null   object
#  2   Description         5967 non-null   object
#  3   Director            3903 non-null   object
#  4   Genres              5967 non-null   object
#  5   Cast                5437 non-null   object
#  6   Production Country  5408 non-null   object
#  7   Release Date        5964 non-null   float64
#  8   Rating              5963 non-null   object
#  9   Duration            5964 non-null   object
#  10  Imdb Score          5359 non-null   object
#  11  Content Type        5967 non-null   object
#  12  Date Added          4632 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 606.1+ KB
#        Release Date
# count   5964.000000
# mean    2015.643863
# ...

# %%
df.head(3)
# Out:
#                                 Show Id                          Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477                       (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb                         #Alive
# 2  b01b73b7-81f6-47a7-86d8-acb63080d525  #AnneFrank - Parallel Stories
#
#                                          Description  \
# 0  This docuseries takes a deep dive into the luc...
# 1  As a grisly virus rampages a city, a lone man ...
# 2  Through her diary, Anne Frank's story is retol...
#
#                       Director  \
# 0                          NaN
# 1                       Cho Il
# 2  Sabina Fedeli, Anna Migotto
#
#                                            Genres  \
# 0                                      Reality TV
# 1  Horror Movies, International Movies, Thrillers
# 2             Documentaries, International Movies
#
#                           Cast Production Country  Release Date Rating  \
# ...

# %%
df.columns
# Out:
# Index(['Show Id', 'Title', 'Description', 'Director', 'Genres', 'Cast',
#        'Production Country', 'Release Date', 'Rating', 'Duration',
#        'Imdb Score', 'Content Type', 'Date Added'],
#       dtype='object')

# %% [markdown]
# **Checking duplicated values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added]
# Index: []

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# Check null values

# %%
df.isnull().sum()
# Out:
# Show Id                  0
# Title                    0
# Description              0
# Director              2064
# Genres                   0
# Cast                   530
# Production Country     559
# Release Date             3
# Rating                   4
# Duration                 3
# Imdb Score             608
# Content Type             0
# Date Added            1335
# dtype: int64

# %%
import seaborn as sns # import seaborn library

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **Q1. For 'House of Cards', what is the Show id and Who is the Director of this show?**

# %%
# df.head()

# %%
df['Title']
# Out:
# 0                            (Un)Well
# 1                              #Alive
# 2       #AnneFrank - Parallel Stories
# 3                            #blackAF
# 4                    #cats_the_mewvie
#                     ...
# 5962                        الف مبروك
# 5963                     دفعة القاهرة
# 5964                             海的儿子
# 5965                          반드시 잡는다
# 5966              최강전사 미니특공대 : 영웅의 탄생
# Name: Title, Length: 5967, dtype: object

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#                                    Show Id           Title  \
# 2130  ec170eff-50b5-4d1d-8418-784fa393d0a8  House of Cards
#
#                                             Description Director  \
# 2130  A ruthless politician will stop at nothing to ...      NaN
#
#                        Genres  \
# 2130  TV Dramas, TV Thrillers
#
#                                                    Cast Production Country  \
# 2130  Kevin Spacey, Robin Wright, Kate Mara, Corey S...      United States
#
#       Release Date Rating   Duration Imdb Score Content Type      Date Added
# 2130        2018.0  TV-MA  6 Seasons     8.7/10      TV Show  April 14, 2021

# %%
# Particular method
df[df['Title'].str.contains('House of Cards')]
# Out:
#                                    Show Id           Title  \
# 2130  ec170eff-50b5-4d1d-8418-784fa393d0a8  House of Cards
#
#                                             Description Director  \
# 2130  A ruthless politician will stop at nothing to ...      NaN
#
#                        Genres  \
# 2130  TV Dramas, TV Thrillers
#
#                                                    Cast Production Country  \
# 2130  Kevin Spacey, Robin Wright, Kate Mara, Corey S...      United States
#
#       Release Date Rating   Duration Imdb Score Content Type      Date Added
# 2130        2018.0  TV-MA  6 Seasons     8.7/10      TV Show  April 14, 2021

# %% [markdown]
# **Q2. In which year highest number of the TV shows & Movies were released? Show with Bar Graph.**

# %%
#df.dtypes

# %%
# datetime format
# df['Date_N'] = pd.to_datetime(df['Release Date'])

# %%
#df.head(2)

# %%
# df['Date_N'].dt.year.value_counts()
# It counts the occurence of all individual Years in Date column

# %%
df['Release Date'].value_counts()
# Out:
# Release Date
# 2019.0    971
# 2020.0    946
# 2018.0    924
# 2017.0    661
# 2016.0    491
#          ...
# 1977.0      1
# 1945.0      1
# 1966.0      1
# 1956.0      1
# 1959.0      1
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# Bar Graph

# %%
df['Release Date'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Release Date'>

# %% [markdown]
# Answer : 2019

# %% [markdown]
# **Q3. How many Movies & TV Shows are in the dataset? Show with Bar Graph.**

# %%
df.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating  Duration Imdb Score Content Type  \
# 0      United States        2020.0  TV-MA  1 Season     6.6/10      TV Show
# 1        South Korea        2020.0  TV-MA    99 min     6.2/10        Movie
#
#           Date Added
# 0                NaN
# 1  September 8, 2020

# %%
df.groupby('Content Type')['Content Type'].count() # To group all unique items of a column and show their count
# Out:
# Content Type
# Movie      3867
# TV Show    2100
# Name: Content Type, dtype: int64

# %%
df['Content Type'].value_counts() # Same method
# Out:
# Content Type
# Movie      3867
# TV Show    2100
# Name: count, dtype: int64

# %% [markdown]
# **countplot()**

# %%
sns.countplot(df['Content Type'])
# Out:
# <Axes: xlabel='count', ylabel='Content Type'>

# %% [markdown]
# **Q.4 Show all the Movies that were released in year 2000.**

# %%
# df.head(2)

# %% [markdown]
# Filtering

# %%
df[(df['Content Type'] == 'Movie') & (df['Release Date'] == 2000.0)]['Title']
# Out:
# 562                          Battlefield Earth
# 940                           Charlie's Angels
# 1652                                      Fiza
# 2417                    Joseph: King of Dreams
# 3176    Monty Python: Before the Flying Circus
# 3689               Phir Bhi Dil Hai Hindustani
# 4022               Rugrats in Paris: The Movie
# 4317                                  Snow Day
# 5110                               The Patriot
# 5305                      The Whole Nine Yards
# Name: Title, dtype: object

# %% [markdown]
# **Q.5. What are the Title of the TV Show released in India?**

# %%
# df.head(2)

# %%
# df[(df['Content Type'] == 'TV Show') & (df['Production Country'] == 'India')]

# %%
df[(df['Content Type'] == 'TV Show') & (df['Production Country'] == 'India')]['Title']
# Out:
# 245                                      Akbar Birbal
# 302                                      Alma Matters
# 510                       Bad Boy Billionaires: India
# 551                                     Bard of Blood
# 622                                            Betaal
# 642                                Bhaag Beanie Bhaag
# 758                                     Bombay Begums
# 1005    ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 1071                                  College Romance
# 1130                    Cricket Fever: Mumbai Indians
# 1256                                      Delhi Crime
# 1500                                Engineering Girls
# 1555                Fabulous Lives of Bollywood Wives
# 1807                                            GHOUL
# 1827                                     Girls Hostel
# 1981                                          Hasmukh
# 2250                                          Inmates
# ...

# %% [markdown]
# **Q.6 Show Top 10 Directors who gave the highest number of TV Shows & Movies to Netflix?**

# %%
# df.head(2)

# %%
df['Director'].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               15
# Jay Karas                 14
# Youssef Chahine           12
# Cathy Garcia-Molina       12
# Jay Chapman               11
# Lance Bangs                8
# Don Michael Paul           8
# Fernando Ayllón            8
# Name: count, dtype: int64

# %% [markdown]
# **Q.7 Show all the Records where "Content Type is Movie and Genres is Comedies" or "Country is UK".**

# %% [markdown]
# Filtering (And/Or operators)

# %%
# df.head(2)

# %%
df[(df['Content Type']=='Movie') & (df['Genres']=='Comedies') | (df['Production Country']=='United Kingdom')].head(2)
# Out:
#                                  Show Id         Title  \
# 7   c844460f-6178-4f87-929e-80816c74ca35  #realityhigh
# 37  5c1f674a-9d13-490a-8809-8e8477701499      21 Again
#
#                                           Description          Director  \
# 7   When nerdy high schooler Dani finally attracts...  Fernando Lebrija
# 37  In a social experiment, a group of daughters s...               NaN
#
#                           Genres  \
# 7                       Comedies
# 37  British TV Shows, Reality TV
#
#                                                  Cast Production Country  \
# 7   Nesta Cooper, Kate Walsh, John Michael Higgins...      United States
# 37                                       Laura Morgan     United Kingdom
#
#     Release Date Rating  Duration Imdb Score Content Type         Date Added  \
# 7         2017.0  TV-14    99 min     5.1/10        Movie  September 8, 2017
# 37        2019.0  TV-MA  1 Season     4.8/10      TV Show                NaN
#
# ...

# %% [markdown]
# **Q.8 How many movies/shows, Tom Cruise was cast?**

# %%
# df.head(2)

# %% [markdown]
# filtering

# %%
df[df['Cast']=='Tom Cruise'] # No Result because cast includes group of actor/actress.
# Out:
# Empty DataFrame
# Columns: [Show Id, Title, Description, Director, Genres, Cast, Production Country, Release Date, Rating, Duration, Imdb Score, Content Type, Date Added]
# Index: []

# %% [markdown]
# **str.contains()**

# %%
# df[df['Cast'].str.contains('Tom Cruise')]

# This code will have errors because 'Cast' columns have NaN/NA values.

# %% [markdown]
# **Create new df to drop Na/NaN values**

# %%
df_new = df.dropna()

# %%
# df_new.head(2)

# %%
# Now apply str.contains() again
df_new[df_new['Cast'].str.contains('Tom Cruise')]
# Out:
#                                    Show Id     Title  \
# 3838  8a3c098b-386a-44e4-a3a3-c5771871597e  Rain Man
#
#                                             Description        Director  \
# 3838  Motivated by money, a selfish workaholic seeki...  Barry Levinson
#
#                       Genres  \
# 3838  Classic Movies, Dramas
#
#                                                    Cast Production Country  \
# 3838  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...      United States
#
#       Release Date Rating Duration Imdb Score Content Type     Date Added
# 3838        1988.0      R  134 min     7.9/10        Movie  March 1, 2021

# %% [markdown]
# **Q.9 What are the different Ratings defined by Netflix?**

# %% [markdown]
# nunique()

# %%
df['Rating'].nunique() # Show the count of types of ratings
# Out:
# 11

# %% [markdown]
# unique()

# %%
df['Rating'].unique() # Show differnt types
# Out:
# array(['TV-MA', 'TV-14', 'TV-G', 'TV-PG', 'TV-Y', 'R', 'PG-13', 'TV-Y7',
#        'PG', 'G', nan, 'NC-17'], dtype=object)

# %% [markdown]
# **Q.9.1 How many Movies got the 'TV-14' rating, in Canada?**

# %%
df[(df['Content Type'] == 'Movie') & (df['Rating']=='TV-14') & (df['Production Country']=='Canada')]
# Out:
#                                    Show Id  \
# 4     7f2d4170-bab8-4d75-adc2-197f7124c070
# 2895  65cacd6d-e99a-4432-84c3-98a3458c94e7
# 2980  3955f108-7b46-4d45-b5f0-b48aaab8b4ba
# 5344  e31cd859-eeb7-4f63-b0ae-d3b8b9c0b882
#
#                                             Title  \
# 4                                #cats_the_mewvie
# 2895   Made You Look: A True Story About Fake Art
# 2980  Martin Matte: La vie, la mort...eh la la..!
# 5344               There's Something in the Water
#
#                                             Description  \
# 4     This pawesome documentary explores how our fel...
# 2895  A woman walks into a New York gallery with a c...
# 2980  Quebecois comedy star Martin Matte serves up e...
# 5344  This documentary spotlights the struggle of mi...
#
#                     Director                               Genres  \
# 4           Michael Margolis  Documentaries, International Movies
# 2895            Barry Avrich  Documentaries, International Movies
# ...

# %%
df[(df['Content Type'] == 'Movie') & (df['Rating']=='TV-14') & (df['Production Country']=='Canada')].shape
# Out:
# (4, 13)

# %% [markdown]
# **Q.9.2. How many TV Show got the 'R' rating, after year 2010?**

# %%
df[(df['Content Type']=='TV Show') & (df['Rating']=='R')].shape
# Out:
# (1, 13)

# %%
df[(df['Content Type']=='TV Show') & (df['Rating']=='R') & (df['Release Date'] > 2010)]
# Out:
#                                    Show Id  \
# 4878  b05b96c3-bf05-43e9-8f3e-427c5ed51500
#
#                                     Title  \
# 4878  The Hateful Eight: Extended Version
#
#                                             Description           Director  \
# 4878  Trapped at a stagecoach stop as a storm rages ...  Quentin Tarantino
#
#         Genres                                               Cast  \
# 4878  TV Shows  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...
#
#      Production Country  Release Date Rating  Duration Imdb Score  \
# 4878                NaN        2015.0      R  1 Season        NaN
#
#      Content Type Date Added
# 4878      TV Show        NaN

# %% [markdown]
# **Q.10. What is the maximum duration of a Movie/Show on Netflix?**

# %%
df.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating  Duration Imdb Score Content Type  \
# 0      United States        2020.0  TV-MA  1 Season     6.6/10      TV Show
# 1        South Korea        2020.0  TV-MA    99 min     6.2/10        Movie
#
#           Date Added
# 0                NaN
# 1  September 8, 2020

# %%
df['Duration'].unique() #show different types of duration
# Out:
# array(['1 Season', '99 min', '95 min', '90 min', '102 min', '104 min',
#        '56 min', '125 min', '119 min', '87 min', '97 min', '109 min',
#        '44 min', '101 min', '89 min', '4 Seasons', '3 Seasons', '84 min',
#        '124 min', '114 min', '130 min', '103 min', '143 min', '107 min',
#        '158 min', '144 min', '78 min', '140 min', '135 min', '117 min',
#        '92 min', '164 min', '93 min', '91 min', '116 min', '2 Seasons',
#        '105 min', '120 min', '96 min', '75 min', '115 min', '129 min',
#        '80 min', '77 min', '148 min', '123 min', '121 min', '131 min',
#        '28 min', '122 min', '94 min', '85 min', '22 min', '86 min',
#        '137 min', '68 min', '29 min', '168 min', '21 min', '59 min',
#        '113 min', '20 min', '108 min', '111 min', '110 min', '100 min',
#        '83 min', '26 min', '156 min', '30 min', '57 min', '82 min',
#        '98 min', '133 min', '154 min', '146 min', '136 min', '106 min',
# ...

# %%
# 'Duration' has two types of data --> Seasons, min
df['Duration'].dtypes
# Out:
# dtype('O')

# %%
# 'O' is object format.
# Change to numeric format.
df.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating  Duration Imdb Score Content Type  \
# 0      United States        2020.0  TV-MA  1 Season     6.6/10      TV Show
# 1        South Korea        2020.0  TV-MA    99 min     6.2/10        Movie
#
#           Date Added
# 0                NaN
# 1  September 8, 2020

# %% [markdown]
# **str.split()**

# %%
# Split like '99' and 'min' into two columns
df[['Minutes', 'Unit']] = df['Duration'].str.split(' ', expand=True)

# %%
df.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating  Duration Imdb Score Content Type  \
# 0      United States        2020.0  TV-MA  1 Season     6.6/10      TV Show
# 1        South Korea        2020.0  TV-MA    99 min     6.2/10        Movie
#
#           Date Added Minutes    Unit
# 0                NaN       1  Season
# 1  September 8, 2020      99     min

# %%
df['Minutes'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# **max()**

# %%
df['Minutes'] = pd.to_numeric(df['Minutes'], errors='coerce') # I googled this

# %%
df['Minutes'].max() #Maxi
# Out:
# 312.0

# %%
df['Minutes'].min()
# Out:
# 1.0

# %%
df['Minutes'].mean()
# Out:
# 64.93645204560697

# %% [markdown]
# Answer: 312 min

# %% [markdown]
# **Q.11. Which individual country has the Highest No. of TV Shows?**

# %%
df.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating  Duration Imdb Score Content Type  \
# 0      United States        2020.0  TV-MA  1 Season     6.6/10      TV Show
# 1        South Korea        2020.0  TV-MA    99 min     6.2/10        Movie
#
#           Date Added  Minutes    Unit
# 0                NaN      1.0  Season
# 1  September 8, 2020     99.0     min

# %%
df_tvshow = df[df['Content Type']=='TV Show']

# %%
df_tvshow.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 3  b6611af0-f53c-4a08-9ffa-9716dc57eb9c  #blackAF
#
#                                          Description Director       Genres  \
# 0  This docuseries takes a deep dive into the luc...      NaN   Reality TV
# 3  Kenya Barris and his family navigate relations...      NaN  TV Comedies
#
#                                                 Cast Production Country  \
# 0                                                NaN      United States
# 3  Kenya Barris, Rashida Jones, Iman Benson, Genn...      United States
#
#    Release Date Rating  Duration Imdb Score Content Type Date Added  Minutes  \
# 0        2020.0  TV-MA  1 Season     6.6/10      TV Show        NaN      1.0
# 3        2020.0  TV-MA  1 Season     6.6/10      TV Show        NaN      1.0
#
#      Unit
# 0  Season
# 3  Season

# %%
df_tvshow['Production Country'].value_counts().head(1)
# Out:
# Production Country
# United States    624
# Name: count, dtype: int64

# %% [markdown]
# Answer: United States

# %% [markdown]
# **How can we sort the dataset by Year?**

# %%
df.head(2)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
# 1  e2ef4e91-fb25-42ab-b485-be8e3b23dedb    #Alive
#
#                                          Description Director  \
# 0  This docuseries takes a deep dive into the luc...      NaN
# 1  As a grisly virus rampages a city, a lone man ...   Cho Il
#
#                                            Genres                      Cast  \
# 0                                      Reality TV                       NaN
# 1  Horror Movies, International Movies, Thrillers  Yoo Ah-in, Park Shin-hye
#
#   Production Country  Release Date Rating  Duration Imdb Score Content Type  \
# 0      United States        2020.0  TV-MA  1 Season     6.6/10      TV Show
# 1        South Korea        2020.0  TV-MA    99 min     6.2/10        Movie
#
#           Date Added  Minutes    Unit
# 0                NaN      1.0  Season
# 1  September 8, 2020     99.0     min

# %% [markdown]
# **sort_values(by=' ', ascending=False)**

# %%
df.sort_values(by='Release Date', ascending=True).head(2)
# Out:
#                                    Show Id  \
# 3706  8a6d8125-7c0f-4ec0-85dd-e1c4fdaaa380
# 1649  95315fd3-1598-4773-95eb-2fc85d733b91
#
#                                     Title  \
# 3706    Pioneers: First Women Filmmakers*
# 1649  Five Came Back: The Reference Films
#
#                                             Description Director    Genres  \
# 3706  This collection restores films from women who ...      NaN  TV Shows
# 1649  This collection includes 12 World War II-era p...      NaN  TV Shows
#
#      Cast Production Country  Release Date Rating  Duration Imdb Score  \
# 3706  NaN                NaN        1925.0  TV-14  1 Season        NaN
# 1649  NaN      United States        1945.0  TV-MA  1 Season     8.3/10
#
#      Content Type Date Added  Minutes    Unit
# 3706      TV Show        NaN      1.0  Season
# 1649      TV Show        NaN      1.0  Season

# %% [markdown]
# **Q.13. Find all the instances where:**
#
# ---
#
# **Category is 'Movie' and Type is 'Dramas' or**
#
# ---
#
# **Category is 'TV Show' & Type is 'Kids' TV'**

# %%
df.head(1)
# Out:
#                                 Show Id     Title  \
# 0  cc1b6ed9-cf9e-4057-8303-34577fb54477  (Un)Well
#
#                                          Description Director      Genres  \
# 0  This docuseries takes a deep dive into the luc...      NaN  Reality TV
#
#   Cast Production Country  Release Date Rating  Duration Imdb Score  \
# 0  NaN      United States        2020.0  TV-MA  1 Season     6.6/10
#
#   Content Type Date Added  Minutes    Unit
# 0      TV Show        NaN      1.0  Season

# %%
df[(df['Content Type']=='Movie')&(df['Genres']=='Dramas')].head(2)
# Out:
#                                   Show Id                       Title  \
# 150  6fc7ebe9-3293-48fd-b556-4113899a6bc5  A Stoning in Fulham County
# 195  6ebd13aa-69d0-4a89-8bcc-5739b408c027          Across Grace Alley
#
#                                            Description       Director  Genres  \
# 150  After reckless teens kill an Amish child, a pr...  Larry Elikann  Dramas
# 195  A young boy, upset by his parents' divorce, be...  Ralph Macchio  Dramas
#
#                                                   Cast Production Country  \
# 150  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...      United States
# 195  Ben Hyland, Marsha Mason, Karina Smirnoff, Col...      United States
#
#      Release Date Rating Duration Imdb Score Content Type        Date Added  \
# 150        1988.0  TV-14   95 min     6.0/10        Movie   October 1, 2011
# 195        2013.0  TV-PG   24 min     6.1/10        Movie  December 1, 2016
#
#      Minutes Unit
# 150     95.0  min
# 195     24.0  min

# %%
# df['Genres'].unique()
# I check are there 'Kids' TV' under column "Genres"

# %%
df[(df['Content Type']=='TV Show') & (df['Genres']=="Kids' TV")].head(2)
# Out:
#                                   Show Id         Title  \
# 54   e14fd618-75bb-4800-b86a-ca3af91bdd67       44 Cats
# 179  2e98c599-e0e8-4dbd-a000-0fa3304bd9a9  Abby Hatcher
#
#                                            Description     Director    Genres  \
# 54   Paw-esome tales abound when singing furry frie...          NaN  Kids' TV
# 179  A big-hearted girl helps her Fuzzly friends wh...  Kyran Kelly  Kids' TV
#
#                                                   Cast     Production Country  \
# 54   Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 179  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
#
#      Release Date Rating   Duration Imdb Score Content Type       Date Added  \
# 54         2018.0  TV-Y7  2 Seasons     6.0/10      TV Show  October 1, 2020
# 179        2019.0   TV-Y   1 Season     5.9/10      TV Show              NaN
#
#      Minutes     Unit
# 54       2.0  Seasons
# 179      1.0   Season

# %%
df[(df['Content Type']=='Movie')&(df['Genres']=='Dramas') | (df['Content Type']=='TV Show') & (df['Genres']=="Kids' TV")].head(2)
# Out:
#                                   Show Id                       Title  \
# 54   e14fd618-75bb-4800-b86a-ca3af91bdd67                     44 Cats
# 150  6fc7ebe9-3293-48fd-b556-4113899a6bc5  A Stoning in Fulham County
#
#                                            Description       Director  \
# 54   Paw-esome tales abound when singing furry frie...            NaN
# 150  After reckless teens kill an Amish child, a pr...  Larry Elikann
#
#        Genres                                               Cast  \
# 54   Kids' TV  Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 150    Dramas  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
#
#     Production Country  Release Date Rating   Duration Imdb Score  \
# 54               Italy        2018.0  TV-Y7  2 Seasons     6.0/10
# 150      United States        1988.0  TV-14     95 min     6.0/10
#
#     Content Type       Date Added  Minutes     Unit
# 54       TV Show  October 1, 2020      2.0  Seasons
# ...
